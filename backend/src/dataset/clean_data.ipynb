# %%
import pandas as pd

# %%
data = pd.read_csv('./HuGaDB_v2_various_01_00.csv')

data.head()
# Out:
#    Unnamed: 0  accelerometer_right_foot_x  accelerometer_right_foot_y  \
# 0           0                       -7868                       -1336
# 1           1                       -7956                       -1384
# 2           2                       -7892                       -1348
# 3           3                       -7856                       -1352
# 4           4                       -7896                       -1356
#
#    accelerometer_right_foot_z  gyroscope_right_foot_x  gyroscope_right_foot_y  \
# 0                       13400                     -28                      26
# 1                       13468                     -20                      28
# 2                       13492                     -18                      24
# 3                       13504                     -16                      23
# 4                       13440                     -13                      26
#
#    gyroscope_right_foot_z  accelerometer_right_shin_x  \
# ...

# %%
# write the first column header as "person_id"
data.rename(columns={data.columns[0]: 'person_id'}, inplace=True)

data.head()
# Out:
#    person_id  accelerometer_right_foot_x  accelerometer_right_foot_y  \
# 0          0                       -7868                       -1336
# 1          1                       -7956                       -1384
# 2          2                       -7892                       -1348
# 3          3                       -7856                       -1352
# 4          4                       -7896                       -1356
#
#    accelerometer_right_foot_z  gyroscope_right_foot_x  gyroscope_right_foot_y  \
# 0                       13400                     -28                      26
# 1                       13468                     -20                      28
# 2                       13492                     -18                      24
# 3                       13504                     -16                      23
# 4                       13440                     -13                      26
#
#    gyroscope_right_foot_z  accelerometer_right_shin_x  \
# ...

# %%
# keep only first 30 rows
data = data.head(30)

data.head()
# Out:
#    person_id  accelerometer_right_foot_x  accelerometer_right_foot_y  \
# 0          0                       -7868                       -1336
# 1          1                       -7956                       -1384
# 2          2                       -7892                       -1348
# 3          3                       -7856                       -1352
# 4          4                       -7896                       -1356
#
#    accelerometer_right_foot_z  gyroscope_right_foot_x  gyroscope_right_foot_y  \
# 0                       13400                     -28                      26
# 1                       13468                     -20                      28
# 2                       13492                     -18                      24
# 3                       13504                     -16                      23
# 4                       13440                     -13                      26
#
#    gyroscope_right_foot_z  accelerometer_right_shin_x  \
# ...

# %%
# save the cleaned data to a new csv file 
data.to_csv('cleaned_data.csv', index=False)

# %%
# get 5 random rows from the data
data.sample(5)
# Out:
#     person_id  accelerometer_right_foot_x  accelerometer_right_foot_y  \
# 29         29                       -7888                       -1220
# 3           3                       -7856                       -1352
# 20         20                       -7884                       -1328
# 14         14                       -7916                       -1316
# 2           2                       -7892                       -1348
#
#     accelerometer_right_foot_z  gyroscope_right_foot_x  \
# 29                       13340                      -8
# 3                        13504                     -16
# 20                       13456                      -8
# 14                       13420                      -9
# 2                        13492                     -18
#
#     gyroscope_right_foot_y  gyroscope_right_foot_z  \
# 29                      22                     -25
# 3                       23                     -21
# 20                      18                     -23
# ...

# %%
# save the test data to a new csv file
data.sample(5).to_csv('test_data.csv', index=False)
